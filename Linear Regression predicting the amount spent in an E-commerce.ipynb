# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#load the dataset
df_import = pd.read_csv('ecommerce.csv')
df_import
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
#check if there are duplicates
df_import.duplicated().sum()
# Out:
# 0

# %%
#check if there are null values
df_import.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
#checking data types
df_import.dtypes
# Out:
# Email                    object
# Address                  object
# Avatar                   object
# Avg. Session Length     float64
# Time on App             float64
# Time on Website         float64
# Length of Membership    float64
# Yearly Amount Spent     float64
# dtype: object

# %%
#statistical analysis
df_import.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
#perform EDA
plt.title('Yearly Amount Spent vs Time on Website')
sns.scatterplot(x='Time on Website', y='Yearly Amount Spent', data = df_import, alpha =0.7)
# Out:
# <Axes: title={'center': 'Yearly Amount Spent vs Time on Website'}, xlabel='Time on Website', ylabel='Yearly Amount Spent'>

# %%
plt.title('Yearly Amount Spent vs Avg. Session Length')
sns.scatterplot(data =df_import, y= 'Yearly Amount Spent', x ='Avg. Session Length', alpha =0.5)
# Out:
# <Axes: title={'center': 'Yearly Amount Spent vs Avg. Session Length'}, xlabel='Avg. Session Length', ylabel='Yearly Amount Spent'>

# %%
plt.title('Yearly Amount Spent vs Time on App')
sns.scatterplot(data = df_import, y ='Yearly Amount Spent',x ='Time on App',alpha=0.5)
# Out:
# <Axes: title={'center': 'Yearly Amount Spent vs Time on App'}, xlabel='Time on App', ylabel='Yearly Amount Spent'>

# %%
plt.title('Yearly Amount Spent vs Length of Membership')
sns.scatterplot(data = df_import, y ='Yearly Amount Spent',x ='Length of Membership',alpha=0.5)
# Out:
# <Axes: title={'center': 'Yearly Amount Spent vs Length of Membership'}, xlabel='Length of Membership', ylabel='Yearly Amount Spent'>

# %%
#Lets split the columns:target and the variables
x = df_import[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
y = df_import['Yearly Amount Spent']

# %%
#Let's split the data into training and testing
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size= 0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([402.86230051, 542.53325708, 426.62011918, 501.91386363,
#        409.6666551 , 569.92155038, 531.50423529, 505.94309188,
#        408.10378607, 473.45942928, 441.18668812, 424.52463471,
#        424.83341694, 527.12061508, 430.87985533, 423.47062047,
#        575.8751518 , 484.6563331 , 457.77896975, 481.58742311,
#        501.56110993, 513.12815188, 507.49166899, 646.63377343,
#        449.70050586, 496.26290484, 556.18523776, 554.78684161,
#        399.1582784 , 325.16921284, 532.62732659, 477.73025415,
#        500.76491535, 305.09971374, 505.46811902, 483.52069444,
#        519.09464122, 437.75549737, 456.25005245, 470.63517876,
#        494.11207805, 444.65549239, 508.57079732, 500.88197484,
#        488.35128728, 535.34025218, 594.58301773, 513.59474408,
#        279.69877702, 432.71590835, 421.06976164, 480.94327496,
#        584.59481888, 608.61734059, 564.42312991, 494.47224504,
#        393.95593318, 456.11321352, 572.92228417, 499.27385693,
# ...

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 361            32.077590    10.347877        39.045156              3.434560
# 73             32.808698    12.817113        37.031539              3.851579
# 374            31.447446    10.101632        38.043453              4.238296
# 155            32.449522    13.457725        37.238806              2.941411
# 104            31.389585    10.994224        38.074452              3.428860
# ..                   ...          ...              ...                   ...
# 347            33.769812    11.304462        37.833972              5.137817
# 86             33.877779    12.517666        37.151921              2.669942
# 75             32.049839    12.238057        38.730862              3.120569
# 438            32.149061    10.047315        37.181447              3.535088
# 15             30.737720    12.636606        36.213763              3.357847
#
# [100 rows x 4 columns]

# %%
df_import.iloc[73]
# Out:
# Email                                        williamsjohnny@ferguson.info
# Address                 51920 Kent Junctions Apt. 352\nWalkerport, NY ...
# Avatar                                                        LightYellow
# Avg. Session Length                                             32.808698
# Time on App                                                     12.817113
# Time on Website                                                 37.031539
# Length of Membership                                             3.851579
# Yearly Amount Spent                                            534.777188
# Name: 73, dtype: object

# %%
regressor.coef_
# Out:
# array([25.5962591 , 38.78534598,  0.31038593, 61.89682859])

# %%
regressor.intercept_
# Out:
# -1044.2574146365591

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.9782625350414405
